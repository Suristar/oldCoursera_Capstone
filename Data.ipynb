# %% [markdown]
# We have the collisions report.
# We are going to use different attributes such as location, severitydesc, pedcount, etc.
# We want to use the data to improve the safety of the pedestrains.
# We will look at the incidents in the past and use the data to try to make the road a safer place for the future.
