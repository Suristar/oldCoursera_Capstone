# %% [markdown]
# How to improve the safety of the pedestrian from the collisions.
# The audience is the transportation and road safety board/department.
# By looking at the data, they can see where the increased amount of collisions happening that involve pedestrains.
# which place and where to improve and put more safety precautions.
